# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
import glob
#from netCDF4 import Dataset

# %%
filesindir = []
for i, file in enumerate(glob.glob('./input/*')):
    filesindir.append(file)
    print(i, file)
#print(filesindir)
# Out:
# 0 ./input\19x37.png
# 1 ./input\20x37.png
# 2 ./input\8x75.png
# 3 ./input\Gap_12x75f2_on_POLf0.txt
# 4 ./input\Gap_REFf2_on_POLf0.txt
# 5 ./input\POL_f3_on_POL_f0.txt
# 6 ./input\RAM12x75_f2_on_POL_f0.txt
# 7 ./input\RAM12x75_f3_on_POL_f0.txt
# 8 ./input\RAM14x75_f3_on_POL_f0.txt
# 9 ./input\RAM14x75_f4_on_POL_f0.txt
# 10 ./input\RAM16x75_f4_on_POL_f0.txt
# 11 ./input\RAM16x75_f5_on_POL_f0.txt
# 12 ./input\RAM17_f3_on_POL_f0.txt
# 13 ./input\RAM17_fanf3_on_POL_f0.txt
# 14 ./input\RAM19_f2_on_POL_f0.txt
# 15 ./input\RAM19_f2_on_POL_f0f1_comb.txt
# 16 ./input\RAM19_f2_on_POL_f0_comb.txt
# 17 ./input\RAM19_f3_on_POL_f0.txt
# 18 ./input\RAM19_f3_on_POL_f0comb.txt
# 19 ./input\RAM19_f3_on_RAM19_f0.txt
# 20 ./input\RAM19_f4_on_POL_f0.A1X
# 21 ./input\RAM19_f4_on_POL_f0.txt
# 22 ./input\RAM19_fanf2_on_POL_f0.txt
# 23 ./input\RAM19_fanf4_on_POL_f0.txt
# 24 ./input\REF_f2_on_POL_f0.txt

# %%
def readtodataframe(file, scenario):
    path = './input/'
    filename = path + file + '.txt'
    column_names = ['BasShotNo', 'MonShotNo', 'BasRecvNo', 'MonRecvNo', 'OffsDiff', 'AzimDiff', 'CMPDist', 'CMPInDist', 'CMPCrDist', 'SouDist', 'SouInDist', 'SouCrDist', 'RecDist', 'RecInDist', 'RecCrDist', 'SouRecDist']
    rowstoskip = 2
    df_raw = pd.read_csv(filename, names=column_names, skiprows=rowstoskip, delim_whitespace=True)
    df_raw['Scenario'] = scenario
    return df_raw

# %%
'''
df_raw_POL_f3_on_POL_f0 = readtodataframe('POL_f3_on_POL_f0', '8x75m on 8x75m')
df_raw_RAM19_f3_on_POL_f0 = readtodataframe('RAM19_f3_on_POL_f0', '19x37.5m on 8x75m')
df_raw_RAM19_f3_on_POL_f0comb = readtodataframe('RAM19_f3_on_POL_f0comb', '19x37.5m on 8x75m inc interleaved')
df_raw_RAM19_f3_on_RAM19_f0 = readtodataframe('RAM19_f3_on_RAM19_f0', '19x37.5m on 19x37.5m')
df_raw_RAM17_f3_on_POL_f0 = readtodataframe('RAM17_f3_on_POL_f0', '17x37.5m on 8x75m')
df_raw_RAM17_fanf3_on_POL_f0 = readtodataframe('RAM17_fanf3_on_POL_f0', '17x37.5m with fan on 8x75m')
'''
# Out:
# "\ndf_raw_POL_f3_on_POL_f0 = readtodataframe('POL_f3_on_POL_f0', '8x75m on 8x75m')\ndf_raw_RAM19_f3_on_POL_f0 = readtodataframe('RAM19_f3_on_POL_f0', '19x37.5m on 8x75m')\ndf_raw_RAM19_f3_on_POL_f0comb = readtodataframe('RAM19_f3_on_POL_f0comb', '19x37.5m on 8x75m inc interleaved')\ndf_raw_RAM19_f3_on_RAM19_f0 = readtodataframe('RAM19_f3_on_RAM19_f0', '19x37.5m on 19x37.5m')\ndf_raw_RAM17_f3_on_POL_f0 = readtodataframe('RAM17_f3_on_POL_f0', '17x37.5m on 8x75m')\ndf_raw_RAM17_fanf3_on_POL_f0 = readtodataframe('RAM17_fanf3_on_POL_f0', '17x37.5m with fan on 8x75m')\n"

# %%
#df_1 = readtodataframe('POL_f3_on_POL_f0', '8x75m - 3deg on 8x75m')
df_1 = readtodataframe('Gap_REFf2_on_POLf0', '10x75.5m - 2deg on 8x75m')
df_2 = readtodataframe('Gap_12x75f2_on_POLf0', '12x75m - 2deg on 8x75m')
#df_3 = readtodataframe('RAM12x75_f3_on_POL_f0', '12x75m - 3deg on 8x75m')
#df_4 = readtodataframe('RAM14x75_f3_on_POL_f0', '14x75m - 3deg on 8x75m')
#df_5 = readtodataframe('RAM16x75_f4_on_POL_f0', '16x75m - 4deg on 8x75m')
#df_6 = readtodataframe('RAM19_f3_on_POL_f0', '19x37.5m - 3deg on 8x75m')
df_3 = readtodataframe('Gap_19x37f2_on_POLf0', '19x37.5m - 2deg on 8x75m')
#df_5 = readtodataframe('RAM19_f3_on_POL_f0', '19x37.5m - 3deg on 8x75m')
df_4 = readtodataframe('RAM19_f4_on_POL_f0', '19x37.5m - 4deg on 8x75m')
df_5 = readtodataframe('RAM19_fanf2_on_POL_f0', '19x37.5m - 150% Fanning - 2deg on 8x75m')
df_6 = readtodataframe('RAM19_fanf4_on_POL_f0', '19x37.5m - 150% Fanning - 4deg on 8x75m')

# %%
'''#df_1 = readtodataframe('POL_f3_on_POL_f0', '8x75m - 3deg on 8x75m')
df_1 = readtodataframe('REF_f2_on_POL_f0', '10x75.5m - 2deg on 8x75m')
df_2 = readtodataframe('Gap_12x75f2_on_POLf0', '12x75m - 2deg on 8x75m')
df_3 = readtodataframe('RAM12x75_f3_on_POL_f0', '12x75m - 3deg on 8x75m')
df_4 = readtodataframe('RAM14x75_f3_on_POL_f0', '14x75m - 3deg on 8x75m')
df_5 = readtodataframe('RAM14x75_f4_on_POL_f0', '14x75m - 4deg on 8x75m')
df_6 = readtodataframe('RAM16x75_f4_on_POL_f0', '16x75m - 4deg on 8x75m')
'''
# Out:
# "#df_1 = readtodataframe('POL_f3_on_POL_f0', '8x75m - 3deg on 8x75m')\ndf_1 = readtodataframe('REF_f2_on_POL_f0', '10x75.5m - 2deg on 8x75m')\ndf_2 = readtodataframe('Gap_12x75f2_on_POLf0', '12x75m - 2deg on 8x75m')\ndf_3 = readtodataframe('RAM12x75_f3_on_POL_f0', '12x75m - 3deg on 8x75m')\ndf_4 = readtodataframe('RAM14x75_f3_on_POL_f0', '14x75m - 3deg on 8x75m')\ndf_5 = readtodataframe('RAM14x75_f4_on_POL_f0', '14x75m - 4deg on 8x75m')\ndf_6 = readtodataframe('RAM16x75_f4_on_POL_f0', '16x75m - 4deg on 8x75m')\n"

# %%
def offset_split(df, channo):
    df['Channel Range'] = df['BasRecvNo'].apply(lambda x: '< '+str(channo) if ((x % 408 < channo) & (x % 408 > 0)) else '> '+str(channo))
    return df

# %%
df_1 = offset_split(df_1, 100)
df_2 = offset_split(df_2, 100)
df_3 = offset_split(df_3, 100)
df_4 = offset_split(df_4, 100)
df_5 = offset_split(df_5, 100)
df_6 = offset_split(df_6, 100)

# %%
df_1.replace(-999.25, np.nan, inplace=True)
df_2.replace(-999.25, np.nan, inplace=True)
df_3.replace(-999.25, np.nan, inplace=True) 
df_4.replace(-999.25, np.nan, inplace=True)
df_5.replace(-999.25, np.nan, inplace=True) 
df_6.replace(-999.25, np.nan, inplace=True)

# %%
df_combined = pd.concat([df_1, 
                         df_2, 
                         df_3, 
                         df_4, 
                         df_5,
                         df_6,])

# %%
def plot_dist(df, attrib, maxval, title, plttype='violin'):
    sns.set_style("darkgrid")
    sns.set_context('poster')
    sns.set_palette('Paired')
    plt.figure(figsize=(20,16))
    plt.title(title)
    plt.xticks(rotation=20)
    plt.gca().invert_yaxis()
    plt.ylim(maxval, -maxval/20)
    if plttype == 'violin':
        sns.violinplot(data=df[df[attrib] <= 70], x='Scenario', y=attrib, hue='Channel Range', split=True, cut=0, scale='count')
        #sns.violinplot(data=df[df[attrib] <= maxval], x='Scenario', y=attrib, split=True, cut=0, scale='count')
        #sns.violinplot(data=df, x='Scenario', y=attrib, hue='Channel Range', split=True, cut=0, scale='count')
    else:
        sns.boxplot(data=df, x='Scenario', y=attrib)#, hue='Channel Range')

# %%
plot_dist(df_combined, 'SouRecDist', 30, 'Delta S + Delta R', plttype='violin')

# %%
plot_dist(df_combined, 'OffsDiff', 10, 'Delta Offset', plttype='violin')

# %%
plot_dist(df_combined, 'SouDist', 50, 'Delta S', plttype='violin')

# %%
plot_dist(df_combined, 'RecDist', 10, 'Delta R', plttype='violin')

# %%
plot_dist(df_combined, 'AzimDiff', 2, 'Delta Azimuth', plttype='violin')

# %%
def make_summary(df, attribute):
    #summary = df.describe(percentiles=[0.1, 0.25, 0.5, 0.9])[['OffsDiff', 'AzimDiff', 'CMPDist', 'CMPInDist', 'CMPCrDist', 'SouDist', 'SouInDist', 'SouCrDist', 'RecDist', 'RecInDist', 'RecCrDist', 'SouRecDist']].round(decimals=1).T
    summary = df.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9])[[attribute]].round(decimals=1)
    #summary['Scenario'] = df[['Scenario']].iloc[0,0]
    #summary = summary.set_index([attribute])
    summary = summary.T
    summary['Scenario'] = df[['Scenario']].iloc[0,0]
    summary = summary.set_index(['Scenario']).reset_index()
    return summary

# %%
def makefullsummary(attribute):
    summary = make_summary(df_1, attribute)
    summary = summary.append(make_summary(df_2, attribute), ignore_index=True)
    summary = summary.append(make_summary(df_3, attribute), ignore_index=True)    
    summary = summary.append(make_summary(df_4, attribute), ignore_index=True)
    summary = summary.append(make_summary(df_5, attribute), ignore_index=True)
    summary = summary.append(make_summary(df_6, attribute), ignore_index=True)
    return summary

# %%
def make_heatmap(df, caption):
    cm = sns.light_palette("red", as_cmap=True)
    s = df.style.set_caption(caption).background_gradient(cmap=cm).hide_index().hide_columns(['count'])
    #s = df.style.set_caption(caption).background_gradient(cmap=cm).hide_index()
    return s

# %%
summary_offsetdiff = makefullsummary('OffsDiff')
make_heatmap(summary_offsetdiff, 'Delta Offset')
# Out:
# <style  type="text/css" >
#     #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col1 {
#             background-color:  #ffe4e4;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col2 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col3 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col5 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col6 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col7 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col8 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col9 {
#             background-color:  #ff9494;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col10 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow1_col1 {
#             background-color:  #ffa4a4;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow1_col2 {
#             background-color:  #ffe3e3;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow1_col3 {
#             background-color:  #ffe1e1;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow1_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow1_col5 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow1_col6 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow1_col7 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow1_col8 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow1_col9 {
#             background-color:  #ff7b7b;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow1_col10 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow2_col1 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow2_col2 {
#             background-color:  #ffd0d0;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow2_col3 {
#             background-color:  #ffc9c9;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow2_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow2_col5 {
#             background-color:  #ffb3b3;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow2_col6 {
#             background-color:  #ffb6b6;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow2_col7 {
#             background-color:  #ffa9a9;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow2_col8 {
#             background-color:  #ffbebe;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow2_col9 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow2_col10 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow3_col1 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow3_col2 {
#             background-color:  #ff3a3a;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow3_col3 {
#             background-color:  #ff4949;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow3_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow3_col5 {
#             background-color:  #ff1919;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow3_col6 {
#             background-color:  #ff0c0c;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow3_col7 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow3_col8 {
#             background-color:  #ff3232;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow3_col9 {
#             background-color:  #ff2020;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow3_col10 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow4_col1 {
#             background-color:  #ffc1c1;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow4_col2 {
#             background-color:  #ff5d5d;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow4_col3 {
#             background-color:  #ff3a3a;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow4_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow4_col5 {
#             background-color:  #ffb3b3;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow4_col6 {
#             background-color:  #ffa9a9;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow4_col7 {
#             background-color:  #ffa2a2;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow4_col8 {
#             background-color:  #ff9999;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow4_col9 {
#             background-color:  #ff0f0f;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow4_col10 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow5_col1 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow5_col2 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow5_col3 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow5_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow5_col5 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow5_col6 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow5_col7 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow5_col8 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow5_col9 {
#             background-color:  #ff0000;
#         }    #T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow5_col10 {
#             background-color:  #ffe5e5;
#         }</style>
# <table id="T_c5adb076_e5ee_11e9_876c_bca8a698b4ac" ><caption>Delta Offset</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col2" >mean</th>
#         <th class="col_heading level0 col3" >std</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >10%</th>
#         <th class="col_heading level0 col6" >25%</th>
#         <th class="col_heading level0 col7" >50%</th>
#         <th class="col_heading level0 col8" >75%</th>
#         <th class="col_heading level0 col9" >90%</th>
#         <th class="col_heading level0 col10" >max</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col0" class="data row0 col0" >10x75.5m - 2deg on 8x75m</td>
#         <td id="T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col2" class="data row0 col2" >5.2</td>
#         <td id="T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col3" class="data row0 col3" >11.9</td>
#         <td id="T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col4" class="data row0 col4" >0</td>
#         <td id="T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col5" class="data row0 col5" >0.2</td>
#         <td id="T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col6" class="data row0 col6" >0.6</td>
#         <td id="T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col7" class="data row0 col7" >1.3</td>
#         <td id="T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col8" class="data row0 col8" >2.4</td>
#         <td id="T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col9" class="data row0 col9" >19.1</td>
#         <td id="T_c5adb076_e5ee_11e9_876c_bca8a698b4acrow0_col10" class="data row0 col10" >74.9</td>
#     </tr

# %%
summary_sourcerecdist = makefullsummary('SouRecDist')
make_heatmap(summary_sourcerecdist, 'Delta S + Delta R')
# Out:
# <style  type="text/css" >
#     #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col1 {
#             background-color:  #ffe4e4;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col2 {
#             background-color:  #ffdfdf;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col3 {
#             background-color:  #ffcfcf;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col4 {
#             background-color:  #ff7272;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col5 {
#             background-color:  #ffe3e3;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col6 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col7 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col8 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col9 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col10 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow1_col1 {
#             background-color:  #ffa4a4;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow1_col2 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow1_col3 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow1_col4 {
#             background-color:  #ff7272;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow1_col5 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow1_col6 {
#             background-color:  #ffe4e4;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow1_col7 {
#             background-color:  #ffe1e1;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow1_col8 {
#             background-color:  #ffe3e3;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow1_col9 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow1_col10 {
#             background-color:  #ff8080;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow2_col1 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow2_col2 {
#             background-color:  #ffa5a5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow2_col3 {
#             background-color:  #ff8282;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow2_col4 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow2_col5 {
#             background-color:  #ff3b3b;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow2_col6 {
#             background-color:  #ff2e2e;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow2_col7 {
#             background-color:  #ff2828;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow2_col8 {
#             background-color:  #ffb6b6;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow2_col9 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow2_col10 {
#             background-color:  #ff8c8c;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow3_col1 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow3_col2 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow3_col3 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow3_col4 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow3_col5 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow3_col6 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow3_col7 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow3_col8 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow3_col9 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow3_col10 {
#             background-color:  #ff3a3a;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow4_col1 {
#             background-color:  #ffc1c1;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow4_col2 {
#             background-color:  #ffbfbf;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow4_col3 {
#             background-color:  #ffc6c6;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow4_col4 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow4_col5 {
#             background-color:  #ff2e2e;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow4_col6 {
#             background-color:  #ff1717;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow4_col7 {
#             background-color:  #ff0f0f;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow4_col8 {
#             background-color:  #ffa6a6;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow4_col9 {
#             background-color:  #ffe4e4;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow4_col10 {
#             background-color:  #ff4545;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow5_col1 {
#             background-color:  #ffe5e5;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow5_col2 {
#             background-color:  #ff7575;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow5_col3 {
#             background-color:  #ff5e5e;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow5_col4 {
#             background-color:  #ff7272;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow5_col5 {
#             background-color:  #ff0303;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow5_col6 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow5_col7 {
#             background-color:  #ff0000;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow5_col8 {
#             background-color:  #ff0808;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow5_col9 {
#             background-color:  #ffdede;
#         }    #T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow5_col10 {
#             background-color:  #ff0000;
#         }</style>
# <table id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4ac" ><caption>Delta S + Delta R</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col2" >mean</th>
#         <th class="col_heading level0 col3" >std</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >10%</th>
#         <th class="col_heading level0 col6" >25%</th>
#         <th class="col_heading level0 col7" >50%</th>
#         <th class="col_heading level0 col8" >75%</th>
#         <th class="col_heading level0 col9" >90%</th>
#         <th class="col_heading level0 col10" >max</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col0" class="data row0 col0" >10x75.5m - 2deg on 8x75m</td>
#         <td id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col2" class="data row0 col2" >21.4</td>
#         <td id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col3" class="data row0 col3" >73.7</td>
#         <td id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col4" class="data row0 col4" >0.1</td>
#         <td id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col5" class="data row0 col5" >1.3</td>
#         <td id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col6" class="data row0 col6" >2.2</td>
#         <td id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col7" class="data row0 col7" >3.9</td>
#         <td id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col8" class="data row0 col8" >7.7</td>
#         <td id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col9" class="data row0 col9" >72.8</td>
#         <td id="T_ce1fc5d4_e5ee_11e9_98d2_bca8a698b4acrow0_col10" class="data row0 col10" >697.1</td>

# %%
summary_sourcedist = makefullsummary('SouDist')
make_heatmap(summary_sourcedist, 'Delta S')
# Out:
# <style  type="text/css" >
#     #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col1 {
#             background-color:  #ffe4e4;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col2 {
#             background-color:  #ffdfdf;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col3 {
#             background-color:  #ffd0d0;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col4 {
#             background-color:  #ff7272;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col5 {
#             background-color:  #ff9999;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col6 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col7 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col8 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col9 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col10 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow1_col1 {
#             background-color:  #ffa4a4;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow1_col2 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow1_col3 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow1_col4 {
#             background-color:  #ff7272;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow1_col5 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow1_col6 {
#             background-color:  #ffb8b8;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow1_col7 {
#             background-color:  #ffc2c2;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow1_col8 {
#             background-color:  #ffe1e1;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow1_col9 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow1_col10 {
#             background-color:  #ffb8b8;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow2_col1 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow2_col2 {
#             background-color:  #ffb2b2;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow2_col3 {
#             background-color:  #ff8181;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow2_col4 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow2_col5 {
#             background-color:  #ff9999;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow2_col6 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow2_col7 {
#             background-color:  #ffb0b0;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow2_col8 {
#             background-color:  #ffe4e4;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow2_col9 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow2_col10 {
#             background-color:  #ffe0e0;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow3_col1 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow3_col2 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow3_col3 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow3_col4 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow3_col5 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow3_col6 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow3_col7 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow3_col8 {
#             background-color:  #ff0303;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow3_col9 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow3_col10 {
#             background-color:  #ff8282;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow4_col1 {
#             background-color:  #ffc1c1;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow4_col2 {
#             background-color:  #ffc9c9;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow4_col3 {
#             background-color:  #ffc2c2;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow4_col4 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow4_col5 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow4_col6 {
#             background-color:  #ff5c5c;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow4_col7 {
#             background-color:  #ff5858;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow4_col8 {
#             background-color:  #ffd6d6;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow4_col9 {
#             background-color:  #ffe0e0;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow4_col10 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow5_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow5_col2 {
#             background-color:  #ff7a7a;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow5_col3 {
#             background-color:  #ff5c5c;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow5_col4 {
#             background-color:  #ffe5e5;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow5_col5 {
#             background-color:  #ff4d4d;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow5_col6 {
#             background-color:  #ff2e2e;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow5_col7 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow5_col8 {
#             background-color:  #ff0000;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow5_col9 {
#             background-color:  #ffdcdc;
#         }    #T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow5_col10 {
#             background-color:  #ff1f1f;
#         }</style>
# <table id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4ac" ><caption>Delta S</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col2" >mean</th>
#         <th class="col_heading level0 col3" >std</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >10%</th>
#         <th class="col_heading level0 col6" >25%</th>
#         <th class="col_heading level0 col7" >50%</th>
#         <th class="col_heading level0 col8" >75%</th>
#         <th class="col_heading level0 col9" >90%</th>
#         <th class="col_heading level0 col10" >max</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col0" class="data row0 col0" >10x75.5m - 2deg on 8x75m</td>
#         <td id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col2" class="data row0 col2" >11.7</td>
#         <td id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col3" class="data row0 col3" >36.6</td>
#         <td id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col4" class="data row0 col4" >0.1</td>
#         <td id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col5" class="data row0 col5" >1.2</td>
#         <td id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col6" class="data row0 col6" >2</td>
#         <td id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col7" class="data row0 col7" >3.4</td>
#         <td id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col8" class="data row0 col8" >5.9</td>
#         <td id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col9" class="data row0 col9" >37.6</td>
#         <td id="T_d68dae94_e5ee_11e9_8fad_bca8a698b4acrow0_col10" class="data row0 col10" >343.8</td>
#     </tr>

# %%
summary_recdist = makefullsummary('RecDist')
make_heatmap(summary_recdist, 'Delta R')
# Out:
# <style  type="text/css" >
#     #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col1 {
#             background-color:  #ffe4e4;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col2 {
#             background-color:  #ffdfdf;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col3 {
#             background-color:  #ffcfcf;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col4 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col5 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col6 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col7 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col8 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col9 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col10 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow1_col1 {
#             background-color:  #ffa4a4;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow1_col2 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow1_col3 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow1_col4 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow1_col5 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow1_col6 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow1_col7 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow1_col8 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow1_col9 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow1_col10 {
#             background-color:  #ffd9d9;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow2_col1 {
#             background-color:  #ff0000;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow2_col2 {
#             background-color:  #ff9a9a;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow2_col3 {
#             background-color:  #ff8484;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow2_col4 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow2_col5 {
#             background-color:  #ff5454;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow2_col6 {
#             background-color:  #ff3434;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow2_col7 {
#             background-color:  #ff2626;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow2_col8 {
#             background-color:  #ff6262;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow2_col9 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow2_col10 {
#             background-color:  #ffb8b8;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow3_col1 {
#             background-color:  #ff0000;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow3_col2 {
#             background-color:  #ff0000;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow3_col3 {
#             background-color:  #ff0000;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow3_col4 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow3_col5 {
#             background-color:  #ff0505;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow3_col6 {
#             background-color:  #ff0303;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow3_col7 {
#             background-color:  #ff0101;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow3_col8 {
#             background-color:  #ff0000;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow3_col9 {
#             background-color:  #ff0000;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow3_col10 {
#             background-color:  #ff3b3b;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow4_col1 {
#             background-color:  #ffc1c1;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow4_col2 {
#             background-color:  #ffb7b7;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow4_col3 {
#             background-color:  #ffcaca;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow4_col4 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow4_col5 {
#             background-color:  #ff4949;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow4_col6 {
#             background-color:  #ff1c1c;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow4_col7 {
#             background-color:  #ff0e0e;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow4_col8 {
#             background-color:  #ff4949;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow4_col9 {
#             background-color:  #ffe4e4;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow4_col10 {
#             background-color:  #ff1717;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow5_col1 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow5_col2 {
#             background-color:  #ff7070;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow5_col3 {
#             background-color:  #ff5f5f;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow5_col4 {
#             background-color:  #ffe5e5;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow5_col5 {
#             background-color:  #ff0000;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow5_col6 {
#             background-color:  #ff0000;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow5_col7 {
#             background-color:  #ff0000;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow5_col8 {
#             background-color:  #ff1010;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow5_col9 {
#             background-color:  #ffdbdb;
#         }    #T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow5_col10 {
#             background-color:  #ff0000;
#         }</style>
# <table id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4ac" ><caption>Delta R</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col2" >mean</th>
#         <th class="col_heading level0 col3" >std</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >10%</th>
#         <th class="col_heading level0 col6" >25%</th>
#         <th class="col_heading level0 col7" >50%</th>
#         <th class="col_heading level0 col8" >75%</th>
#         <th class="col_heading level0 col9" >90%</th>
#         <th class="col_heading level0 col10" >max</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col0" class="data row0 col0" >10x75.5m - 2deg on 8x75m</td>
#         <td id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col2" class="data row0 col2" >9.7</td>
#         <td id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col3" class="data row0 col3" >37.3</td>
#         <td id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col4" class="data row0 col4" >0</td>
#         <td id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col5" class="data row0 col5" >0</td>
#         <td id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col6" class="data row0 col6" >0</td>
#         <td id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col7" class="data row0 col7" >0</td>
#         <td id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col8" class="data row0 col8" >0</td>
#         <td id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col9" class="data row0 col9" >31.7</td>
#         <td id="T_df62bbe6_e5ee_11e9_b168_bca8a698b4acrow0_col10" class="data row0 col10" >356</td>
#     </tr>    <tr>

# %%
summary_azmdiff = makefullsummary('AzimDiff')
make_heatmap(summary_azmdiff, 'Delta Azimuth')
# Out:
# <style  type="text/css" >
#     #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col1 {
#             background-color:  #ffe4e4;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col2 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col3 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col5 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col6 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col7 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col8 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col9 {
#             background-color:  #ffe3e3;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col10 {
#             background-color:  #ffc1c1;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow1_col1 {
#             background-color:  #ffa4a4;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow1_col2 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow1_col3 {
#             background-color:  #ffc0c0;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow1_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow1_col5 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow1_col6 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow1_col7 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow1_col8 {
#             background-color:  #ffd6d6;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow1_col9 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow1_col10 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow2_col1 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow2_col2 {
#             background-color:  #ffb0b0;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow2_col3 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow2_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow2_col5 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow2_col6 {
#             background-color:  #ff7272;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow2_col7 {
#             background-color:  #ff4d4d;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow2_col8 {
#             background-color:  #ffa8a8;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow2_col9 {
#             background-color:  #ffd4d4;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow2_col10 {
#             background-color:  #ffbbbb;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow3_col1 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow3_col2 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow3_col3 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow3_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow3_col5 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow3_col6 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow3_col7 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow3_col8 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow3_col9 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow3_col10 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow4_col1 {
#             background-color:  #ffc1c1;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow4_col2 {
#             background-color:  #ffbdbd;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow4_col3 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow4_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow4_col5 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow4_col6 {
#             background-color:  #ff7272;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow4_col7 {
#             background-color:  #ff4d4d;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow4_col8 {
#             background-color:  #ff7a7a;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow4_col9 {
#             background-color:  #ffdcdc;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow4_col10 {
#             background-color:  #ff6f6f;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow5_col1 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow5_col2 {
#             background-color:  #ff7a7a;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow5_col3 {
#             background-color:  #ff8080;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow5_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow5_col5 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow5_col6 {
#             background-color:  #ff7272;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow5_col7 {
#             background-color:  #ff0000;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow5_col8 {
#             background-color:  #ff6b6b;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow5_col9 {
#             background-color:  #ffa5a5;
#         }    #T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow5_col10 {
#             background-color:  #ff6767;
#         }</style>
# <table id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4ac" ><caption>Delta Azimuth</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col2" >mean</th>
#         <th class="col_heading level0 col3" >std</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >10%</th>
#         <th class="col_heading level0 col6" >25%</th>
#         <th class="col_heading level0 col7" >50%</th>
#         <th class="col_heading level0 col8" >75%</th>
#         <th class="col_heading level0 col9" >90%</th>
#         <th class="col_heading level0 col10" >max</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col0" class="data row0 col0" >10x75.5m - 2deg on 8x75m</td>
#         <td id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col2" class="data row0 col2" >0.5</td>
#         <td id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col3" class="data row0 col3" >1.9</td>
#         <td id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col4" class="data row0 col4" >0</td>
#         <td id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col5" class="data row0 col5" >0</td>
#         <td id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col6" class="data row0 col6" >0</td>
#         <td id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col7" class="data row0 col7" >0.1</td>
#         <td id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col8" class="data row0 col8" >0.2</td>
#         <td id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col9" class="data row0 col9" >1.3</td>
#         <td id="T_e7cf329e_e5ee_11e9_9385_bca8a698b4acrow0_col10" class="data row0 col10" >75.7</td>
#     </tr>

# %%
cm = sns.light_palette("green", as_cmap=True)
s = summary_sourcerecdist[['Scenario','count']].style.set_caption('Number of Traces').background_gradient(cmap=cm).hide_index()

# %%
s
# Out:
# <style  type="text/css" >
#     #T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow0_col1 {
#             background-color:  #e4fee4;
#         }    #T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow1_col1 {
#             background-color:  #a4dba4;
#         }    #T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow2_col1 {
#             background-color:  #008000;
#         }    #T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow3_col1 {
#             background-color:  #008000;
#         }    #T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow4_col1 {
#             background-color:  #c1ebc1;
#         }    #T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow5_col1 {
#             background-color:  #e5ffe5;
#         }</style>
# <table id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4ac" ><caption>Number of Traces</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col1" >count</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow0_col0" class="data row0 col0" >10x75.5m - 2deg on 8x75m</td>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow0_col1" class="data row0 col1" >1.4172e+06</td>
#     </tr>    <tr>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow1_col0" class="data row1 col0" >12x75m - 2deg on 8x75m</td>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow1_col1" class="data row1 col1" >1.4242e+06</td>
#     </tr>    <tr>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow2_col0" class="data row2 col0" >19x37.5m - 2deg on 8x75m</td>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow2_col1" class="data row2 col1" >1.44226e+06</td>
#     </tr>    <tr>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow3_col0" class="data row3 col0" >19x37.5m - 4deg on 8x75m</td>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow3_col1" class="data row3 col1" >1.44223e+06</td>
#     </tr>    <tr>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow4_col0" class="data row4 col0" >19x37.5m - 150% Fanning - 2deg on 8x75m</td>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow4_col1" class="data row4 col1" >1.4211e+06</td>
#     </tr>    <tr>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow5_col0" class="data row5 col0" >19x37.5m - 150% Fanning - 4deg on 8x75m</td>
#         <td id="T_e7d5e99c_e5ee_11e9_b920_bca8a698b4acrow5_col1" class="data row5 col1" >1.41698e+06</td>
#     </tr></tbody>
# </table>

# %%
df_combined.describe()
# Out:
#           BasShotNo     MonShotNo     BasRecvNo     MonRecvNo      OffsDiff  \
# count  8.563969e+06  8.563969e+06  8.563969e+06  8.563969e+06  8.563969e+06
# mean   1.238643e+03  1.234391e+03  1.639168e+03  3.883619e+03  8.177921e+00
# std    5.334955e+02  5.756530e+02  9.748496e+02  1.935395e+03  1.432050e+01
# min    4.900000e+01  4.900000e+01  1.000000e+00  4.000000e+00  3.079320e-07
# 25%    6.750000e+02  6.580000e+02  7.690000e+02  2.342000e+03  1.016840e+00
# 50%    1.344000e+03  1.100000e+03  1.636000e+03  3.585000e+03  2.354980e+00
# 75%    1.801000e+03  1.552000e+03  2.508000e+03  5.436000e+03  5.369970e+00
# max    2.426000e+03  2.426000e+03  3.264000e+03  7.752000e+03  7.499040e+01
#
#            AzimDiff       CMPDist     CMPInDist     CMPCrDist       SouDist  \
# count  8.563967e+06  8.563969e+06  8.563969e+06  8.563969e+06  8.563969e+06
# mean   1.047214e+00  4.339224e+00  4.048227e+00  1.055424e+00  2.580336e+01
# std    2.547666e+00  2.845175e+00  2.949956e+00  8.482820e-01  6.819470e+01
# min    0.000000e+00  3.088160e-03  0.000000e+00  0.000000e+00  2.329470e-02
# 25%    7.845480e-02  1.886390e+00  1.444820e+00  3.750000e-01  2.168430e+00
# 50%    2.240030e-01  3.788980e+00  3.498050e+00  8.422850e-01  3.954120e+00
# 75%    7.417550e-01  6.517440e+00  6.333500e+00  1.545900e+00  7.301820e+00
# max    9.361690e+01  2.198370e+01  2.176710e+01  1.052200e+01  3.549780e+02
#
#           SouInDist     SouCrDist       RecDist     RecInDist     RecCrDist  \
# count  8.563969e+06  8.563969e+06  8.563969e+06  8.563969e+06  8.563969e+06
# mean   2.454213e+01  4.154673e+00  2.800848e+01  2.675290e+01  4.391139e+00
# std    6.811726e+01  7.536003e+00  6.736425e+01  6.732918e+01  7.361951e+00
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.545900e+00  5.273440e-01  0.000000e+00  0.000000e+00  0.000000e+00
# 50%    3.558590e+00  1.166020e+00  8.767140e+00  7.915040e+00  1.416020e+00
# 75%    6.881840e+00  2.238280e+00  1.710470e+01  1.645120e+01  3.946290e+00
# max    3.518810e+02  1.467190e+02  3.628940e+02  3.623600e+02  1.500000e+02
#
#          SouRecDist
# count  8.563969e+06
# mean   5.381184e+01
# std    1.353296e+02
# min    2.329470e-02
# 25%    5.579900e+00
# 50%    1.256340e+01
# 75%    2.110300e+01
# max    7.083590e+02

# %%
df_3.describe().T
# Out:
#                 count         mean          std           min          25%  \
# BasShotNo   1442258.0  1238.234927   532.711645  4.900000e+01   676.000000
# MonShotNo   1442258.0  1213.047100   530.605888  4.900000e+01   662.000000
# BasRecvNo   1442258.0  1637.490541   972.847040  1.000000e+00   771.000000
# MonRecvNo   1442258.0  4481.034494  1928.237998  2.400000e+01  2798.000000
# OffsDiff    1442258.0     5.929771    12.476518  1.130020e-06     1.046080
# AzimDiff    1442257.0     0.870517     1.859348  8.537740e-07     0.122815
# CMPDist     1442258.0     5.105993     2.782342  3.088160e-03     2.723030
# CMPInDist   1442258.0     4.902707     2.902919  0.000000e+00     2.446290
# CMPCrDist   1442258.0     0.951981     0.665478  0.000000e+00     0.403320
# SouDist     1442258.0    21.603733    64.276892  2.329470e-02     2.037150
# SouInDist   1442258.0    20.518398    64.251375  0.000000e+00     1.332030
# SouCrDist   1442258.0     3.013150     6.318035  9.765620e-04     0.508789
# RecDist     1442258.0    27.092802    62.643427  0.000000e+00     5.738220
# RecInDist   1442258.0    26.243414    62.623664  0.000000e+00     5.286130
# RecCrDist   1442258.0     3.281362     6.083708  0.000000e+00     0.814453
# SouRecDist  1442258.0    48.696535   126.731890  2.329470e-02     9.431270
#
#                     50%          75%         max
# BasShotNo   1336.000000  1800.000000  2426.00000
# MonShotNo   1107.000000  1775.000000  2393.00000
# BasRecvNo   1632.000000  2502.000000  3264.00000
# MonRecvNo   4432.000000  6187.000000  7752.00000
# OffsDiff       2.180865     3.753270    74.97600
# AzimDiff       0.257896     0.622047    76.22350
# CMPDist        4.980570     7.272580    15.31340
# CMPInDist      4.839360     7.171880    15.30080
# CMPCrDist      0.848145     1.387210     9.20264
# SouDist        3.660830     6.159360   344.11100
# SouInDist      3.262700     5.708010   343.70800
# SouCrDist      1.071290     1.991210    57.10450
# RecDist       10.955500    16.275200   357.36600
# RecInDist     10.538100    15.772500   356.74500
# RecCrDist      1.606450     2.520510    56.51660
# SouRecDist    14.683300    20.156200   701.47700
