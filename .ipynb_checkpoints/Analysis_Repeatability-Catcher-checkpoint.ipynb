# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np
from scipy import stats
import glob

# %%
filesindir = []
for file in glob.glob('./input/*'):
    filesindir.append(file)
print(filesindir)
# Out:
# ['./input\\POL_f3_on_POL_f0.txt', './input\\RAM17_f3_on_POL_f0.txt', './input\\RAM17_fanf3_on_POL_f0.txt', './input\\RAM19_f3_on_POL_f0.txt', './input\\RAM19_f3_on_POL_f0comb.txt', './input\\RAM19_f3_on_RAM19_f0.txt']

# %%
def readtodataframe(file, scenario):
    path = './input/'
    filename = path + file + '.txt'
    column_names = ['BasShotNo', 'MonShotNo', 'BasRecvNo', 'MonRecvNo', 'OffsDiff', 'AzimDiff', 'CMPDist', 'CMPInDist', 'CMPCrDist', 'SouDist', 'SouInDist', 'SouCrDist', 'RecDist', 'RecInDist', 'RecCrDist', 'SouRecDist']
    rowstoskip = 2
    df_raw = pd.read_csv(filename, names=column_names, skiprows=rowstoskip, delim_whitespace=True)
    df_raw['Scenario'] = scenario
    return df_raw

# %%
df_raw_POL_f3_on_POL_f0 = readtodataframe('POL_f3_on_POL_f0', '8x75m on 8x75m')
df_raw_RAM19_f3_on_POL_f0 = readtodataframe('RAM19_f3_on_POL_f0', '19x37.5m on 8x75m')
df_raw_RAM19_f3_on_POL_f0comb = readtodataframe('RAM19_f3_on_POL_f0comb', '19x37.5m on 8x75m inc interleaved')
df_raw_RAM19_f3_on_RAM19_f0 = readtodataframe('RAM19_f3_on_RAM19_f0', '19x37.5m on 19x37.5m')
df_raw_RAM17_f3_on_POL_f0 = readtodataframe('RAM17_f3_on_POL_f0', '17x37.5m on 8x75m')
df_raw_RAM17_fanf3_on_POL_f0 = readtodataframe('RAM17_fanf3_on_POL_f0', '17x37.5m with fan on 8x75m')

# %%
def offset_split(df, channo):
    df['Channel Range'] = df['BasRecvNo'].apply(lambda x: '< '+str(channo) if ((x % 408 < channo) & (x % 408 > 0)) else '> '+str(channo))
    return df

# %%
df_raw_POL_f3_on_POL_f0 = offset_split(df_raw_POL_f3_on_POL_f0, 100)
df_raw_RAM17_f3_on_POL_f0 = offset_split(df_raw_RAM17_f3_on_POL_f0, 100)
df_raw_RAM17_fanf3_on_POL_f0 = offset_split(df_raw_RAM17_fanf3_on_POL_f0, 100)
df_raw_RAM19_f3_on_POL_f0 = offset_split(df_raw_RAM19_f3_on_POL_f0, 100)
df_raw_RAM19_f3_on_POL_f0comb = offset_split(df_raw_RAM19_f3_on_POL_f0comb, 100)
df_raw_RAM19_f3_on_RAM19_f0 = offset_split(df_raw_RAM19_f3_on_RAM19_f0, 100)

# %%
df_raw_POL_f3_on_POL_f0.replace(-999.25, np.nan, inplace=True)
df_raw_RAM17_f3_on_POL_f0.replace(-999.25, np.nan, inplace=True)
df_raw_RAM17_fanf3_on_POL_f0.replace(-999.25, np.nan, inplace=True) 
df_raw_RAM19_f3_on_POL_f0.replace(-999.25, np.nan, inplace=True)
df_raw_RAM19_f3_on_POL_f0comb.replace(-999.25, np.nan, inplace=True) 
df_raw_RAM19_f3_on_RAM19_f0.replace(-999.25, np.nan, inplace=True)

# %%
df_combined = pd.concat([df_raw_POL_f3_on_POL_f0, 
                         df_raw_RAM19_f3_on_POL_f0, 
                         df_raw_RAM19_f3_on_POL_f0comb, 
                         df_raw_RAM17_f3_on_POL_f0, 
                         df_raw_RAM17_fanf3_on_POL_f0,
                         df_raw_RAM19_f3_on_RAM19_f0,])

# %%
def plot_dist(df, attrib, maxval, title, plttype='violin'):
    sns.set_style("darkgrid")
    sns.set_context('poster')
    sns.set_palette('Paired')
    plt.figure(figsize=(20,16))
    plt.title(title)
    plt.xticks(rotation=20)
    plt.gca().invert_yaxis()
    plt.ylim(maxval, -maxval/20)
    if plttype == 'violin':
        #sns.violinplot(data=df[df[attrib] <= maxval], x='Scenario', y=attrib, hue='Channel Range', split=True, cut=0, scale='count')
        #sns.violinplot(data=df[df[attrib] <= maxval], x='Scenario', y=attrib, split=True, cut=0, scale='count')
        sns.violinplot(data=df, x='Scenario', y=attrib, hue='Channel Range', split=True, cut=0, scale='count')
    else:
        sns.boxplot(data=df[df[attrib] <= maxval], x='Scenario', y=attrib, hue='Channel Range')

# %%
plot_dist(df_combined, 'SouRecDist', 150, 'Delta S + Delta R', plttype='violin')

# %%
plot_dist(df_combined, 'SouDist', 75, 'Delta S', plttype='violin')

# %%
plot_dist(df_combined, 'RecDist', 150, 'Delta R', plttype='violin')

# %%
plot_dist(df_combined, 'AzimDiff', 10, 'Delta Azimuth', plttype='violin')

# %%
def make_summary(df, attribute):
    #summary = df.describe(percentiles=[0.1, 0.25, 0.5, 0.9])[['OffsDiff', 'AzimDiff', 'CMPDist', 'CMPInDist', 'CMPCrDist', 'SouDist', 'SouInDist', 'SouCrDist', 'RecDist', 'RecInDist', 'RecCrDist', 'SouRecDist']].round(decimals=1).T
    summary = df.describe(percentiles=[0.1, 0.25, 0.5, 0.75, 0.9])[[attribute]].round(decimals=1)
    #summary['Scenario'] = df[['Scenario']].iloc[0,0]
    #summary = summary.set_index([attribute])
    summary = summary.T
    summary['Scenario'] = df[['Scenario']].iloc[0,0]
    summary = summary.set_index(['Scenario']).reset_index()
    return summary

# %%
def makefullsummary(attribute):
    summary = make_summary(df_raw_POL_f3_on_POL_f0, attribute)
    summary = summary.append(make_summary(df_raw_RAM19_f3_on_POL_f0, attribute), ignore_index=True)
    summary = summary.append(make_summary(df_raw_RAM19_f3_on_POL_f0comb, attribute), ignore_index=True)    
    summary = summary.append(make_summary(df_raw_RAM17_f3_on_POL_f0, attribute), ignore_index=True)
    summary = summary.append(make_summary(df_raw_RAM17_fanf3_on_POL_f0, attribute), ignore_index=True)
    summary = summary.append(make_summary(df_raw_RAM19_f3_on_RAM19_f0, attribute), ignore_index=True)
    return summary

# %%
def make_heatmap(df, caption):
    cm = sns.light_palette("red", as_cmap=True)
    s = df.style.set_caption(caption).background_gradient(cmap=cm).hide_index().hide_columns(['count'])
    #s = df.style.set_caption(caption).background_gradient(cmap=cm).hide_index()
    return s

# %%
summary_offsetdiff = makefullsummary('OffsDiff')
make_heatmap(summary_offsetdiff, 'Delta Offset')
# Out:
# <style  type="text/css" >
#     #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col1 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col2 {
#             background-color:  #ff0000;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col3 {
#             background-color:  #ff0000;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col5 {
#             background-color:  #ff0000;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col6 {
#             background-color:  #ff0000;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col7 {
#             background-color:  #ff0000;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col8 {
#             background-color:  #ff0000;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col9 {
#             background-color:  #ff0000;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col10 {
#             background-color:  #ff1111;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow1_col1 {
#             background-color:  #ff2b2b;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow1_col2 {
#             background-color:  #ffa7a7;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow1_col3 {
#             background-color:  #ff4a4a;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow1_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow1_col5 {
#             background-color:  #ffa7a7;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow1_col6 {
#             background-color:  #ffaaaa;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow1_col7 {
#             background-color:  #ffd8d8;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow1_col8 {
#             background-color:  #ffdede;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow1_col9 {
#             background-color:  #ff4c4c;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow1_col10 {
#             background-color:  #ff1111;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow2_col1 {
#             background-color:  #ff0404;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow2_col2 {
#             background-color:  #ff9f9f;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow2_col3 {
#             background-color:  #ff4141;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow2_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow2_col5 {
#             background-color:  #ff9292;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow2_col6 {
#             background-color:  #ffa2a2;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow2_col7 {
#             background-color:  #ffd3d3;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow2_col8 {
#             background-color:  #ffd9d9;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow2_col9 {
#             background-color:  #ff5555;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow2_col10 {
#             background-color:  #ff1111;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow3_col1 {
#             background-color:  #ff2b2b;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow3_col2 {
#             background-color:  #ff9b9b;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow3_col3 {
#             background-color:  #ff3c3c;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow3_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow3_col5 {
#             background-color:  #ffa7a7;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow3_col6 {
#             background-color:  #ffb3b3;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow3_col7 {
#             background-color:  #ffd6d6;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow3_col8 {
#             background-color:  #ffd8d8;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow3_col9 {
#             background-color:  #ff3f3f;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow3_col10 {
#             background-color:  #ff1111;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow4_col1 {
#             background-color:  #ff6f6f;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow4_col2 {
#             background-color:  #ff8686;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow4_col3 {
#             background-color:  #ff1b1b;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow4_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow4_col5 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow4_col6 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow4_col7 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow4_col8 {
#             background-color:  #ffc5c5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow4_col9 {
#             background-color:  #ff2727;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow4_col10 {
#             background-color:  #ff0000;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow5_col1 {
#             background-color:  #ff0000;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow5_col2 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow5_col3 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow5_col4 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow5_col5 {
#             background-color:  #ffbcbc;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow5_col6 {
#             background-color:  #ffbbbb;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow5_col7 {
#             background-color:  #ffdfdf;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow5_col8 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow5_col9 {
#             background-color:  #ffe5e5;
#         }    #T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow5_col10 {
#             background-color:  #ffe5e5;
#         }</style>
# <table id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4ac" ><caption>Delta Offset</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col2" >mean</th>
#         <th class="col_heading level0 col3" >std</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >10%</th>
#         <th class="col_heading level0 col6" >25%</th>
#         <th class="col_heading level0 col7" >50%</th>
#         <th class="col_heading level0 col8" >75%</th>
#         <th class="col_heading level0 col9" >90%</th>
#         <th class="col_heading level0 col10" >max</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col0" class="data row0 col0" >8x75m on 8x75m</td>
#         <td id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col2" class="data row0 col2" >20.9</td>
#         <td id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col3" class="data row0 col3" >18.1</td>
#         <td id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col4" class="data row0 col4" >0</td>
#         <td id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col5" class="data row0 col5" >1.8</td>
#         <td id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col6" class="data row0 col6" >4.4</td>
#         <td id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col7" class="data row0 col7" >16.9</td>
#         <td id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col8" class="data row0 col8" >35.1</td>
#         <td id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col9" class="data row0 col9" >45.2</td>
#         <td id="T_c4b2633a_ddce_11e9_a0e4_bca8a698b4acrow0_col10" class="data row0 col10" >74.9</td>
#     </tr>    <t

# %%
summary_sourcerecdist = makefullsummary('SouRecDist')
make_heatmap(summary_sourcerecdist, 'Delta S + Delta R')
# Out:
# <style  type="text/css" >
#     #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col1 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col2 {
#             background-color:  #ff0000;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col3 {
#             background-color:  #ff0000;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col4 {
#             background-color:  #ff7272;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col5 {
#             background-color:  #ff0000;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col6 {
#             background-color:  #ff0000;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col7 {
#             background-color:  #ff0000;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col8 {
#             background-color:  #ff0000;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col9 {
#             background-color:  #ff0000;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col10 {
#             background-color:  #ff0000;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow1_col1 {
#             background-color:  #ff2b2b;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow1_col2 {
#             background-color:  #ff8e8e;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow1_col3 {
#             background-color:  #ff5252;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow1_col4 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow1_col5 {
#             background-color:  #ffa1a1;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow1_col6 {
#             background-color:  #ffafaf;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow1_col7 {
#             background-color:  #ffdbdb;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow1_col8 {
#             background-color:  #ffd6d6;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow1_col9 {
#             background-color:  #ff1f1f;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow1_col10 {
#             background-color:  #ff0707;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow2_col1 {
#             background-color:  #ff0404;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow2_col2 {
#             background-color:  #ffc7c7;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow2_col3 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow2_col4 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow2_col5 {
#             background-color:  #ff9b9b;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow2_col6 {
#             background-color:  #ffafaf;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow2_col7 {
#             background-color:  #ffdbdb;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow2_col8 {
#             background-color:  #ffd4d4;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow2_col9 {
#             background-color:  #ff9494;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow2_col10 {
#             background-color:  #ffe2e2;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow3_col1 {
#             background-color:  #ff2b2b;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow3_col2 {
#             background-color:  #ff5f5f;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow3_col3 {
#             background-color:  #ff2626;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow3_col4 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow3_col5 {
#             background-color:  #ff9b9b;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow3_col6 {
#             background-color:  #ffa8a8;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow3_col7 {
#             background-color:  #ffd9d9;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow3_col8 {
#             background-color:  #ffc0c0;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow3_col9 {
#             background-color:  #ff1919;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow3_col10 {
#             background-color:  #ff0505;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow4_col1 {
#             background-color:  #ff6f6f;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow4_col2 {
#             background-color:  #ffbaba;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow4_col3 {
#             background-color:  #ff9e9e;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow4_col4 {
#             background-color:  #ff0000;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow4_col5 {
#             background-color:  #ffbaba;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow4_col6 {
#             background-color:  #ffb1b1;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow4_col7 {
#             background-color:  #ffd9d9;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow4_col8 {
#             background-color:  #ff6767;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow4_col9 {
#             background-color:  #ffcece;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow4_col10 {
#             background-color:  #ff0f0f;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow5_col1 {
#             background-color:  #ff0000;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow5_col2 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow5_col3 {
#             background-color:  #ffd1d1;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow5_col4 {
#             background-color:  #ff7272;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow5_col5 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow5_col6 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow5_col7 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow5_col8 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow5_col9 {
#             background-color:  #ffe5e5;
#         }    #T_ce457064_ddce_11e9_8f64_bca8a698b4acrow5_col10 {
#             background-color:  #ffe5e5;
#         }</style>
# <table id="T_ce457064_ddce_11e9_8f64_bca8a698b4ac" ><caption>Delta S + Delta R</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col2" >mean</th>
#         <th class="col_heading level0 col3" >std</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >10%</th>
#         <th class="col_heading level0 col6" >25%</th>
#         <th class="col_heading level0 col7" >50%</th>
#         <th class="col_heading level0 col8" >75%</th>
#         <th class="col_heading level0 col9" >90%</th>
#         <th class="col_heading level0 col10" >max</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col0" class="data row0 col0" >8x75m on 8x75m</td>
#         <td id="T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col2" class="data row0 col2" >175</td>
#         <td id="T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col3" class="data row0 col3" >232.3</td>
#         <td id="T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col4" class="data row0 col4" >0.1</td>
#         <td id="T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col5" class="data row0 col5" >9.9</td>
#         <td id="T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col6" class="data row0 col6" >16.7</td>
#         <td id="T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col7" class="data row0 col7" >76.6</td>
#         <td id="T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col8" class="data row0 col8" >101.1</td>
#         <td id="T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col9" class="data row0 col9" >600.4</td>
#         <td id="T_ce457064_ddce_11e9_8f64_bca8a698b4acrow0_col10" class="data row0 col10" >712.1</td>

# %%
summary_sourcedist = makefullsummary('SouDist')
make_heatmap(summary_sourcedist, 'Delta S')
# Out:
# <style  type="text/css" >
#     #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col1 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col2 {
#             background-color:  #ff0000;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col3 {
#             background-color:  #ff0000;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col4 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col5 {
#             background-color:  #ff0000;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col6 {
#             background-color:  #ff0000;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col7 {
#             background-color:  #ff0000;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col8 {
#             background-color:  #ff0000;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col9 {
#             background-color:  #ff0000;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col10 {
#             background-color:  #ff0101;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow1_col1 {
#             background-color:  #ff2b2b;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow1_col2 {
#             background-color:  #ff8e8e;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow1_col3 {
#             background-color:  #ff5252;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow1_col4 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow1_col5 {
#             background-color:  #ffacac;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow1_col6 {
#             background-color:  #ffb4b4;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow1_col7 {
#             background-color:  #ffdcdc;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow1_col8 {
#             background-color:  #ffd3d3;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow1_col9 {
#             background-color:  #ff1e1e;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow1_col10 {
#             background-color:  #ff1717;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow2_col1 {
#             background-color:  #ff0404;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow2_col2 {
#             background-color:  #ffc5c5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow2_col3 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow2_col4 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow2_col5 {
#             background-color:  #ffacac;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow2_col6 {
#             background-color:  #ffb4b4;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow2_col7 {
#             background-color:  #ffdcdc;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow2_col8 {
#             background-color:  #ffd1d1;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow2_col9 {
#             background-color:  #ff9191;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow2_col10 {
#             background-color:  #ffd9d9;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow3_col1 {
#             background-color:  #ff2b2b;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow3_col2 {
#             background-color:  #ff6060;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow3_col3 {
#             background-color:  #ff2626;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow3_col4 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow3_col5 {
#             background-color:  #ffcaca;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow3_col6 {
#             background-color:  #ffb4b4;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow3_col7 {
#             background-color:  #ffdcdc;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow3_col8 {
#             background-color:  #ffbdbd;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow3_col9 {
#             background-color:  #ff1a1a;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow3_col10 {
#             background-color:  #ff0a0a;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow4_col1 {
#             background-color:  #ff6f6f;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow4_col2 {
#             background-color:  #ffb7b7;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow4_col3 {
#             background-color:  #ff9e9e;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow4_col4 {
#             background-color:  #ff0000;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow4_col5 {
#             background-color:  #ff9090;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow4_col6 {
#             background-color:  #ffb4b4;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow4_col7 {
#             background-color:  #ffdada;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow4_col8 {
#             background-color:  #ff4444;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow4_col9 {
#             background-color:  #ffc8c8;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow4_col10 {
#             background-color:  #ff0000;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow5_col1 {
#             background-color:  #ff0000;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow5_col2 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow5_col3 {
#             background-color:  #ffd2d2;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow5_col4 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow5_col5 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow5_col6 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow5_col7 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow5_col8 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow5_col9 {
#             background-color:  #ffe5e5;
#         }    #T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow5_col10 {
#             background-color:  #ffe5e5;
#         }</style>
# <table id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4ac" ><caption>Delta S</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col2" >mean</th>
#         <th class="col_heading level0 col3" >std</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >10%</th>
#         <th class="col_heading level0 col6" >25%</th>
#         <th class="col_heading level0 col7" >50%</th>
#         <th class="col_heading level0 col8" >75%</th>
#         <th class="col_heading level0 col9" >90%</th>
#         <th class="col_heading level0 col10" >max</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col0" class="data row0 col0" >8x75m on 8x75m</td>
#         <td id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col2" class="data row0 col2" >86.2</td>
#         <td id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col3" class="data row0 col3" >117.3</td>
#         <td id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col4" class="data row0 col4" >0</td>
#         <td id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col5" class="data row0 col5" >1.9</td>
#         <td id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col6" class="data row0 col6" >4.1</td>
#         <td id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col7" class="data row0 col7" >39.5</td>
#         <td id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col8" class="data row0 col8" >48.2</td>
#         <td id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col9" class="data row0 col9" >300.3</td>
#         <td id="T_d86a0fd2_ddce_11e9_8d42_bca8a698b4acrow0_col10" class="data row0 col10" >352</td>
#     </tr>    <tr>

# %%
summary_recdist = makefullsummary('RecDist')
make_heatmap(summary_recdist, 'Delta R')
# Out:
# <style  type="text/css" >
#     #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col1 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col2 {
#             background-color:  #ff0000;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col3 {
#             background-color:  #ff0000;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col5 {
#             background-color:  #ff0000;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col6 {
#             background-color:  #ff0000;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col7 {
#             background-color:  #ff0000;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col8 {
#             background-color:  #ff0000;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col9 {
#             background-color:  #ff0000;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col10 {
#             background-color:  #ff1212;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow1_col1 {
#             background-color:  #ff2b2b;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow1_col2 {
#             background-color:  #ff8e8e;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow1_col3 {
#             background-color:  #ff5353;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow1_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow1_col5 {
#             background-color:  #ffb7b7;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow1_col6 {
#             background-color:  #ffc8c8;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow1_col7 {
#             background-color:  #ffd3d3;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow1_col8 {
#             background-color:  #ffcfcf;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow1_col9 {
#             background-color:  #ff2222;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow1_col10 {
#             background-color:  #ff0000;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow2_col1 {
#             background-color:  #ff0404;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow2_col2 {
#             background-color:  #ffc9c9;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow2_col3 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow2_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow2_col5 {
#             background-color:  #ffb7b7;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow2_col6 {
#             background-color:  #ffc8c8;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow2_col7 {
#             background-color:  #ffd1d1;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow2_col8 {
#             background-color:  #ffcccc;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow2_col9 {
#             background-color:  #ff9999;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow2_col10 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow3_col1 {
#             background-color:  #ff2b2b;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow3_col2 {
#             background-color:  #ff5e5e;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow3_col3 {
#             background-color:  #ff2727;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow3_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow3_col5 {
#             background-color:  #ffa6a6;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow3_col6 {
#             background-color:  #ffc2c2;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow3_col7 {
#             background-color:  #ffcbcb;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow3_col8 {
#             background-color:  #ffb5b5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow3_col9 {
#             background-color:  #ff1616;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow3_col10 {
#             background-color:  #ff0000;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow4_col1 {
#             background-color:  #ff6f6f;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow4_col2 {
#             background-color:  #ffbfbf;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow4_col3 {
#             background-color:  #ff9e9e;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow4_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow4_col5 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow4_col6 {
#             background-color:  #ffcbcb;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow4_col7 {
#             background-color:  #ffcbcb;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow4_col8 {
#             background-color:  #ffacac;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow4_col9 {
#             background-color:  #ffd5d5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow4_col10 {
#             background-color:  #ff0c0c;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow5_col1 {
#             background-color:  #ff0000;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow5_col2 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow5_col3 {
#             background-color:  #ffd0d0;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow5_col4 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow5_col5 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow5_col6 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow5_col7 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow5_col8 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow5_col9 {
#             background-color:  #ffe5e5;
#         }    #T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow5_col10 {
#             background-color:  #ffe5e5;
#         }</style>
# <table id="T_e1d21510_ddce_11e9_95cd_bca8a698b4ac" ><caption>Delta R</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col2" >mean</th>
#         <th class="col_heading level0 col3" >std</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >10%</th>
#         <th class="col_heading level0 col6" >25%</th>
#         <th class="col_heading level0 col7" >50%</th>
#         <th class="col_heading level0 col8" >75%</th>
#         <th class="col_heading level0 col9" >90%</th>
#         <th class="col_heading level0 col10" >max</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col0" class="data row0 col0" >8x75m on 8x75m</td>
#         <td id="T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col2" class="data row0 col2" >88.8</td>
#         <td id="T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col3" class="data row0 col3" >115.2</td>
#         <td id="T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col4" class="data row0 col4" >0</td>
#         <td id="T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col5" class="data row0 col5" >6.5</td>
#         <td id="T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col6" class="data row0 col6" >13</td>
#         <td id="T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col7" class="data row0 col7" >35.6</td>
#         <td id="T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col8" class="data row0 col8" >56.6</td>
#         <td id="T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col9" class="data row0 col9" >300.2</td>
#         <td id="T_e1d21510_ddce_11e9_95cd_bca8a698b4acrow0_col10" class="data row0 col10" >360.9</td>
#     </tr>    <tr>

# %%
summary_azmdiff = makefullsummary('AzimDiff')
make_heatmap(summary_azmdiff, 'Delta Azimuth')
# Out:
# <style  type="text/css" >
#     #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col1 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col2 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col3 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col4 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col5 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col6 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col7 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col8 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col9 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col10 {
#             background-color:  #ff8383;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow1_col1 {
#             background-color:  #ff2b2b;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow1_col2 {
#             background-color:  #ffa9a9;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow1_col3 {
#             background-color:  #ff9999;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow1_col4 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow1_col5 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow1_col6 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow1_col7 {
#             background-color:  #ffd3d3;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow1_col8 {
#             background-color:  #ffd2d2;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow1_col9 {
#             background-color:  #ff5e5e;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow1_col10 {
#             background-color:  #ffa1a1;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow2_col1 {
#             background-color:  #ff0404;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow2_col2 {
#             background-color:  #ffbdbd;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow2_col3 {
#             background-color:  #ff7070;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow2_col4 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow2_col5 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow2_col6 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow2_col7 {
#             background-color:  #ffd3d3;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow2_col8 {
#             background-color:  #ffcece;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow2_col9 {
#             background-color:  #ffb0b0;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow2_col10 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow3_col1 {
#             background-color:  #ff2b2b;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow3_col2 {
#             background-color:  #ff7a7a;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow3_col3 {
#             background-color:  #ff6666;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow3_col4 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow3_col5 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow3_col6 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow3_col7 {
#             background-color:  #ffc0c0;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow3_col8 {
#             background-color:  #ffb9b9;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow3_col9 {
#             background-color:  #ff4242;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow3_col10 {
#             background-color:  #ff9191;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow4_col1 {
#             background-color:  #ff6f6f;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow4_col2 {
#             background-color:  #ffbdbd;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow4_col3 {
#             background-color:  #ffb3b3;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow4_col4 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow4_col5 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow4_col6 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow4_col7 {
#             background-color:  #ffc0c0;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow4_col8 {
#             background-color:  #ffcece;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow4_col9 {
#             background-color:  #ffcbcb;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow4_col10 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow5_col1 {
#             background-color:  #ff0000;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow5_col2 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow5_col3 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow5_col4 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow5_col5 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow5_col6 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow5_col7 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow5_col8 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow5_col9 {
#             background-color:  #ffe5e5;
#         }    #T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow5_col10 {
#             background-color:  #ffcece;
#         }</style>
# <table id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4ac" ><caption>Delta Azimuth</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col2" >mean</th>
#         <th class="col_heading level0 col3" >std</th>
#         <th class="col_heading level0 col4" >min</th>
#         <th class="col_heading level0 col5" >10%</th>
#         <th class="col_heading level0 col6" >25%</th>
#         <th class="col_heading level0 col7" >50%</th>
#         <th class="col_heading level0 col8" >75%</th>
#         <th class="col_heading level0 col9" >90%</th>
#         <th class="col_heading level0 col10" >max</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col0" class="data row0 col0" >8x75m on 8x75m</td>
#         <td id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col2" class="data row0 col2" >4</td>
#         <td id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col3" class="data row0 col3" >5.9</td>
#         <td id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col4" class="data row0 col4" >0</td>
#         <td id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col5" class="data row0 col5" >0.1</td>
#         <td id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col6" class="data row0 col6" >0.3</td>
#         <td id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col7" class="data row0 col7" >1.4</td>
#         <td id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col8" class="data row0 col8" >6.1</td>
#         <td id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col9" class="data row0 col9" >10.8</td>
#         <td id="T_eb1c0b46_ddce_11e9_9e50_bca8a698b4acrow0_col10" class="data row0 col10" >71.3</td>
#     </tr>    <tr>

# %%
cm = sns.light_palette("green", as_cmap=True)
s = summary_sourcerecdist[['Scenario','count']].style.set_caption('Number of Traces').background_gradient(cmap=cm).hide_index()

# %%
s
# Out:
# <style  type="text/css" >
#     #T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow0_col1 {
#             background-color:  #e5ffe5;
#         }    #T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow1_col1 {
#             background-color:  #2b982b;
#         }    #T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow2_col1 {
#             background-color:  #048204;
#         }    #T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow3_col1 {
#             background-color:  #2b982b;
#         }    #T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow4_col1 {
#             background-color:  #6fbd6f;
#         }    #T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow5_col1 {
#             background-color:  #008000;
#         }</style>
# <table id="T_eb229b86_ddce_11e9_ad03_bca8a698b4ac" ><caption>Number of Traces</caption>
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Scenario</th>
#         <th class="col_heading level0 col1" >count</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow0_col0" class="data row0 col0" >8x75m on 8x75m</td>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow0_col1" class="data row0 col1" >1.35129e+06</td>
#     </tr>    <tr>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow1_col0" class="data row1 col0" >19x37.5m on 8x75m</td>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow1_col1" class="data row1 col1" >1.44221e+06</td>
#     </tr>    <tr>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow2_col0" class="data row2 col0" >19x37.5m on 8x75m inc interleaved</td>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow2_col1" class="data row2 col1" >1.46161e+06</td>
#     </tr>    <tr>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow3_col0" class="data row3 col0" >17x37.5m on 8x75m</td>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow3_col1" class="data row3 col1" >1.44222e+06</td>
#     </tr>    <tr>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow4_col0" class="data row4 col0" >17x37.5m with fan on 8x75m</td>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow4_col1" class="data row4 col1" >1.40941e+06</td>
#     </tr>    <tr>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow5_col0" class="data row5 col0" >19x37.5m on 19x37.5m</td>
#         <td id="T_eb229b86_ddce_11e9_ad03_bca8a698b4acrow5_col1" class="data row5 col1" >1.4636e+06</td>
#     </tr></tbody>
# </table>

# %%
df_combined.describe()
# Out:
#           BasShotNo     MonShotNo     BasRecvNo     MonRecvNo      OffsDiff  \
# count  8.570353e+06  8.570353e+06  8.570353e+06  8.570353e+06  8.570353e+06
# mean   1.280434e+03  1.175301e+03  1.867406e+03  3.877015e+03  1.134839e+01
# std    6.373310e+02  5.348745e+02  1.319286e+03  2.012094e+03  1.566970e+01
# min    4.900000e+01  4.900000e+01  1.000000e+00  1.000000e+00  8.844610e-07
# 25%    6.770000e+02  6.430000e+02  8.360000e+02  2.254000e+03  2.391050e+00
# 50%    1.359000e+03  1.083000e+03  1.697000e+03  3.650000e+03  4.777060e+00
# 75%    1.815000e+03  1.526000e+03  2.648000e+03  5.592000e+03  8.797350e+00
# max    4.561000e+03  2.395000e+03  7.377000e+03  7.752000e+03  7.497220e+01
#
#            AzimDiff       CMPDist     CMPInDist     CMPCrDist       SouDist  \
# count  8.570349e+06  8.570353e+06  8.570353e+06  8.570353e+06  8.570353e+06
# mean   1.747797e+00  5.238277e+00  4.722531e+00  1.652894e+00  4.137856e+01
# std    3.780086e+00  2.658755e+00  2.911168e+00  9.996322e-01  8.751015e+01
# min    0.000000e+00  1.953120e-03  0.000000e+00  0.000000e+00  9.814330e-03
# 25%    1.415300e-01  3.084500e+00  2.245120e+00  7.983400e-01  2.268670e+00
# 50%    3.465710e-01  4.982850e+00  4.574220e+00  1.627440e+00  4.152240e+00
# 75%    1.243280e+00  7.243110e+00  6.975100e+00  2.445800e+00  3.549540e+01
# max    9.146600e+01  3.019710e+01  3.006400e+01  1.064890e+01  3.522080e+02
#
#           SouInDist     SouCrDist       RecDist     RecInDist     RecCrDist  \
# count  8.570353e+06  8.570353e+06  8.570353e+06  8.570353e+06  8.570353e+06
# mean   3.988098e+01  5.269753e+00  4.600756e+01  4.419519e+01  6.748446e+00
# std    8.762760e+01  8.564649e+00  8.522330e+01  8.555759e+01  7.800677e+00
# min    9.765620e-04  9.765620e-04  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.690430e+00  5.947270e-01  7.160420e+00  5.865230e+00  1.816410e+00
# 50%    3.739260e+00  1.282230e+00  1.295740e+01  1.206640e+01  3.962890e+00
# 75%    9.569340e+00  2.718750e+00  2.715610e+01  2.046880e+01  6.435550e+00
# max    3.516890e+02  1.136170e+02  3.640830e+02  3.636900e+02  1.121910e+02
#
#          SouRecDist
# count  8.570353e+06
# mean   8.738613e+01
# std    1.725615e+02
# min    1.104850e-02
# 25%    1.074750e+01
# 50%    1.658580e+01
# 75%    6.630610e+01
# max    7.121070e+02

# %%
df_combined.median()
# Out:
# BasShotNo     1359.000000
# MonShotNo     1083.000000
# BasRecvNo     1697.000000
# MonRecvNo     3650.000000
# OffsDiff         4.777060
# AzimDiff         0.346571
# CMPDist          4.982850
# CMPInDist        4.574220
# CMPCrDist        1.627440
# SouDist          4.152240
# SouInDist        3.739260
# SouCrDist        1.282230
# RecDist         12.957400
# RecInDist       12.066400
# RecCrDist        3.962890
# SouRecDist      16.585800
# dtype: float64
